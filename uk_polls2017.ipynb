# %%
import pandas as pd

# %% [markdown]
# Data I got from the BBC website back when, and I re-exported from my old Tableau Public visualisation, see
# https://tableautziaimesa.blogspot.com/2017/06/pollster-pollster-what-do-you-know.html

# %%
uk_polls_2017=pd.read_csv('Sheet1_data.csv',parse_dates=[0]).drop(columns='median').dropna(axis='rows',how='any')

# %%
uk_polls_2017['Pivot Field Names'].unique()
# Out:
# array(['Ukip', 'Grn', 'SNP', 'LD', 'Lab', 'Con'], dtype=object)

# %%
(uk_polls_2017
 .set_index(['date2','Poll','Pivot Field Names'])['%']
 .unstack()
 .Con
 .unstack()
 #.sort_index()
 .plot(rot=90,ls='',marker='.')
 .legend(loc='center left',bbox_to_anchor=(1.1, 0.5))
)

# %%
(uk_polls_2017
 .set_index(['date2','Poll','Pivot Field Names'])['%']
 .unstack()
 .Con
 .unstack()
 .sort_index()
 .interpolate()
 .plot(rot=90,marker='.',alpha=0.5)
 .legend(loc='center left',bbox_to_anchor=(1.1, 0.5))
)

# %%
(uk_polls_2017
 .set_index(['date2','Poll','Pivot Field Names'])['%']
 .unstack()
 .Lab
 .unstack()
 #.sort_index()
 .plot(rot=90,ls='',marker='.')
 .legend(loc='center left',bbox_to_anchor=(1.1, 0.5))
)

# %%
(uk_polls_2017
 .set_index(['date2','Poll','Pivot Field Names'])['%']
 .unstack()
 .Lab
 .unstack()
 .sort_index()
 .interpolate()
 .plot(rot=90,marker='.')
 .legend(loc='center left',bbox_to_anchor=(1.1, 0.5))
)

# %%
(uk_polls_2017
 .set_index(['date2','Poll','Pivot Field Names'])['%']
 .unstack()
 .SNP
 .unstack()
 #.sort_index()
 .plot(rot=90,ls='',marker='.')
 .legend(loc='center left',bbox_to_anchor=(1.1, 0.5))
)

# %% [markdown]
# SNP's percentages are low enough at the UK scale that it's buried in quantisation noise (1% accuracy for data)

# %%
(uk_polls_2017
 .set_index(['date2','Poll','Pivot Field Names'])['%']
 .unstack()
 .SNP
 .unstack()
 .sort_index()
 .interpolate()
 .plot(rot=90,marker='.')
 .legend(loc='center left',bbox_to_anchor=(1.1, 0.5))
)
