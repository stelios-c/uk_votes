# %% [markdown]
# # Edinburgh local government by-election results September 2026

# %%
import pandas as pd

# %%
pd.options.plotting.backend = "plotly"

# %%
craigmillar_portobello=pd.read_html('https://www.edinburgh.gov.uk/local-government-election-4/local-government-election-results-1')

# %%
craigmillar_portobello[0]
# Out:
#                  Candidate                                     Party  \
# 0  Ballantine, David Craig        Alliance for Democracy and Freedom
# 1         Deepnarain, Niel  Scottish Family Party – Christian Values
# 2            Gregson, Pete                  Workers Party of Britain
# 3       Martinico, Lorenzo                           Scottish Greens
# 4         McGilvray, Silas             Scottish National Party (SNP)
# 5       McLaughlin, Andrew                                 Reform UK
# 6             Olech, Peter                Communist Party of Britain
# 7               Owen, Liss                Scottish Liberal Democrats
# 8        Wyke, Jim Patrick                     Scottish Labour Party
# 9             Young, Haris        Scottish Conservative and Unionist
#
#    First preference votes
# 0                      28
# 1                      73
# 2                      58
# 3                    1781
# 4                    1531
# 5                     569
# 6                      22
# 7                     365
# 8                    1413
# 9                     522

# %%
(craigmillar_portobello[0]
 .assign(candidate_party=craigmillar_portobello[0].Candidate+craigmillar_portobello[0].Party)
 .set_index(['candidate_party'])
 .sort_values('First preference votes')
 ['First preference votes']
 .plot(kind='barh')
)
# Out:
# <div>                            <div id="00dc977f-f34b-4403-aa24-21851c30a964" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00dc977f-f34b-4403-aa24-21851c30a964")) {                    Plotly.newPlot(                        "00dc977f-f34b-4403-aa24-21851c30a964",                        [{"alignmentgroup":"True","hovertemplate":"variable=First preference votes\u003cbr\u003evalue=%{x}\u003cbr\u003ecandidate_party=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"First preference votes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"First preference votes","offsetgroup":"First preference votes","orientation":"h","showlegend":true,"textposition":"auto","x":[22,28,58,73,365,522,569,1413,1531,1781],"xaxis":"x","y":["Olech, PeterCommunist Party of Britain","Ballantine, David CraigAlliance for Democracy and Freedom","Gregson, PeteWorkers Party of Britain","Deepnarain, NielScottish Family Party – Christian Values","Owen, LissScottish Liberal Democrats","Young, HarisScottish Conservative and Unionist","McLaughlin, AndrewReform UK","Wyke, Jim PatrickScottish Labour Party","McGilvray, SilasScottish National Party (SNP)","Martinico, LorenzoScottish Greens"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fi ...

# %%
southside_newington=pd.read_html('https://www.edinburgh.gov.uk/local-government-election-4/local-government-election-results-1/2')

# %%
southside_newington[0]
# Out:
#                      Candidate                                     Party  \
# 0                Elliott, Ruth                     Scottish Labour Party
# 1                Emms, Derrick           Edinburgh & East Lothian People
# 2   Gastel Alejandre, Isabella                           Scottish Greens
# 3          Keirdashian, Roisin                               Independent
# 4              Khovanov, Artie                Scottish Liberal Democrats
# 5                 Layden, Nick        Scottish Conservative and Unionist
# 6         Lucas, Richard Crewe  Scottish Family Party – Christian Values
# 7     Mackenzie, Sam Alexander             Scottish National Party (SNP)
# 8        Moffat, Sean McGregor        Alliance for Democracy and Freedom
# 9                  Neill, Gary                                 Reform UK
# 10          Rowbotham, Markham           Edinburgh & East Lothian People
# 11          Shillcock, Richard                Communist Party of Britain
# 12             Wilkinson, Marc           Edinburgh & East Lothian People
#
#     First preference votes
# 0                     2153
# 1                        9
# 2                     1978
# 3                       63
# 4                      543
# 5                      717
# 6                       38
# 7                      757
# 8                       12
# 9                      305
# 10                       7
# 11                      46
# 12                      78

# %%
(southside_newington[0]
 .assign(candidate_party=southside_newington[0].Candidate+southside_newington[0].Party)
 .set_index(['candidate_party'])
 .sort_values('First preference votes')
 ['First preference votes']
 .plot(kind='barh')
)
# Out:
# <div>                            <div id="b4965180-1117-48f1-b09d-624b2d748081" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4965180-1117-48f1-b09d-624b2d748081")) {                    Plotly.newPlot(                        "b4965180-1117-48f1-b09d-624b2d748081",                        [{"alignmentgroup":"True","hovertemplate":"variable=First preference votes\u003cbr\u003evalue=%{x}\u003cbr\u003ecandidate_party=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"First preference votes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"First preference votes","offsetgroup":"First preference votes","orientation":"h","showlegend":true,"textposition":"auto","x":[7,9,12,38,46,63,78,305,543,717,757,1978,2153],"xaxis":"x","y":["Rowbotham, MarkhamEdinburgh & East Lothian People","Emms, DerrickEdinburgh & East Lothian People","Moffat, Sean McGregorAlliance for Democracy and Freedom","Lucas, Richard CreweScottish Family Party – Christian Values","Shillcock, RichardCommunist Party of Britain","Keirdashian, RoisinIndependent","Wilkinson, MarcEdinburgh & East Lothian People","Neill, GaryReform UK","Khovanov, ArtieScottish Liberal Democrats","Layden, NickScottish Conservative and Unionist","Mackenzie, Sam AlexanderScottish National Party (SNP)","Gastel Alejandre, IsabellaScottish Greens","Elliott, RuthScottish Labour Party"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777 ...
